# %% [markdown]
# This notebook is part of the Practical Cheminformatics tutorials series.  The complete series can be found at [this link](https://github.com/PatWalters/practical_cheminformatics_tutorials).

# %% [markdown]
# ### Streamlining Cheminformatics Workflows with [datamol](https://datamol.io) 1. Data manipulation, descriptors, and clustering
#
# The [datamol](datamol.io) package from the M2D2 group provides a set of functions that simplify some common Cheminformatics tasks.  The best part of this package is that it builds on the RDKit. All the RDKit functionality you know and love is there, it's just easier to access.  In this notebook I'll highlight some basic data manipulation capabilities available in datamol.
# - Transforming units
# - Adding molecules and descriptors to Pandas dataframes
# - Filtering dataframes based on descriptor values
# - Clustering

# %% [markdown]
# Install the necessary Python libraries

# %%
# %pip install pandas rdkit datamol tqdm mols2grid

# %% [markdown]
# Import the necessary Python libraries

# %%
import pandas as pd
import datamol as dm
from tqdm.auto import tqdm
from rdkit.Chem import rdDepictor
import mols2grid

# %% [markdown]
# ### A few preliminary settings
# A couple settings to get us started.  Let's make sure our chemical structures will look good and that floating point values aren't shown with a ridiculous number of decimal places.

# %%
rdDepictor.SetPreferCoordGen(True)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Reading data
# Read an input dataset.  There are a couple of things to notice here.
# - The input data doesn't have column headers, we use the "names" argument to [**pd.read_csv**](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) to specify column names.
# - We are using a space as a delimiter, this is specified in the **sep** argument.

# %%
from read_csv import read_csv

# %%
url = "https://raw.githubusercontent.com/PatWalters/yamc/main/data/HERG.smi"
df = read_csv(url, sep=" ", names=["SMILES", "Name", "pIC50"])

# %%
df.head()

# %% [markdown]
# ### Transforming units
# This data has the pIC50, or the log10 of the IC50 in $\mu$M.  Whenever I look at pIC50 values I end up mentally converting them to IC50 values.  I've become pretty good at this, but I'd prefer to have the IC50 values in the table. Fortunately, datamol has a set of convenience methods in the [**dm.molar**](https://docs.datamol.io/0.8.5/api/datamol.molar.html) package that do this conversion.  This isn't something that's hard to do, but it's nice to have a simple function available to handle the conversion. For more on **dm.molar** consult the docs.
# ```python
# help(dm.molar)
# ```

# %% [markdown]
# # IC50 and pIC50
#
# IC50 and pIC50 are two ways of expressing the same thing: how potent a compound is at inhibiting some biological target (an enzyme, receptor, etc.).
#
# ## IC50
#
# **IC50** — "half-maximal inhibitory concentration." It's the concentration of a compound needed to inhibit the target by 50%. It's a real physical concentration, usually measured in molar (M) or nanomolar (nM).
#
# **Lower IC50 = more potent**, because you need less of the compound to get the effect.
#
# ## pIC50
#
# **pIC50** — the negative log (base 10) of the IC50 expressed in molar:
#
# $$\text{pIC50} = -\log_{10}(\text{IC50 in M})$$
#
# The transformation flips the direction and compresses the scale, so **higher pIC50 = more potent** (the opposite direction from IC50).
#
# ## Worked examples
#
# | IC50   | IC50 in M | pIC50 |
# |--------|-----------|-------|
# | 1 µM   | 10⁻⁶      | 6     |
# | 100 nM | 10⁻⁷      | 7     |
# | 10 nM  | 10⁻⁸      | 8     |
# | 1 nM   | 10⁻⁹      | 9     |
#
# ## Why people use pIC50
#
# - **IC50 values span many orders of magnitude** (millimolar to picomolar), which is awkward to plot and average. Taking the log turns that into a compact, roughly linear scale — usually single digits between ~4 and ~10.
# - **Averaging is more meaningful** in log space. Potency data is log-normally distributed, so you should average pIC50 values, not raw IC50 values.
# - **It relates linearly to binding free energy**, which is physically what a medicinal chemist cares about.
# ## Reversing the conversion
#
# To go from pIC50 back to a concentration (what the `dm.molar` step does):
#
# $$\text{IC50 in M} = 10^{-\text{pIC50}}$$
#
# So a pIC50 of 7 means an IC50 of 10⁻⁷ M = 100 nM. That's the mental math you're offloading to `dm.molar` — going from the log-scale pIC50 in the table back to a concentration you can intuitively read.

# %%
help(dm.molar)

# %% [markdown]
# df['IC50'] = dm.molar.log_to_molar(df.pIC50,'uM')
# df.head()

# %%
df['IC50'] = dm.molar.log_to_molar(df.pIC50,'uM')
df.head()

# %% [markdown]
# Log to molar explained · MD
# That line converts your log-scale pIC50 column back into real IC50 concentrations and adds them as a new column.
#
# Breaking it down:
#
# - `df.pIC50` — the existing column of pIC50 values.
# - `dm.molar.log_to_molar(df.pIC50, 'uM')` — datamol's helper that undoes the log. It takes each pIC50, computes 10^(−pIC50) to get the concentration in molar, then converts that to the unit you asked for. The `'uM'` argument means the output is expressed in **micromolar (µM)**.
# - `df['IC50'] = ...` — stores the result as a new column called `IC50`.
# - `df.head()` — shows the first 5 rows so you can eyeball the result.
# So after this, your table has a new `IC50` column in µM sitting next to `pIC50`. A quick sanity check on the values:
#
# | pIC50 | IC50 in M | IC50 in µM |
# |-------|-----------|------------|
# | 6     | 10⁻⁶      | 1          |
# | 7     | 10⁻⁷      | 0.1        |
# | 8     | 10⁻⁸      | 0.01       |
#
# So a pIC50 of 7 should show up as `0.1` in the new `IC50` column. If the numbers in `df.head()` line up with that pattern, the conversion worked as intended.
#
# One thing worth confirming in the output: check that the `IC50` values look sensible (small positive numbers, more potent compounds having smaller IC50). If anything looks off by orders of magnitude, the unit string `'uM'` is the first place to look.

# %% [markdown]
# ### Adding a molecule to a dataframe
# The datamol function [**from_df**](https://docs.datamol.io/stable/api/datamol.convert.html) provides a convenient means of adding an RDKit molecule column to a dataframe.

# %%
df['mol'] = dm.from_df(df, smiles_column="SMILES")
df.head()

# %% [markdown]
# ### Calculating simple 1D descriptors
# The datamol package has a function [**batch_compute_many_descriptors**](https://docs.datamol.io/stable/api/datamol.descriptors.html) that calculates many of the molecular descriptors supported by the RDKit.  When called with the default arguments, this function calculates 22 different descriptors. While this is useful, I usually only want to add a few descriptors to a dataframe.  We can do this by passing a dictionary to the **properties_fn** argument of **batch_compute_many_descriptors**.  The key for this dictionary is the name of the resulting dataframe column and the value is the function that will be called to calculate the descriptor. This function should take an RDKit molecule as an argument. These functions don't necessarily have to be datamol or RDKit functions.  You can also add your own functions. For instance let's define a function to get the size of the largest ring in a molecule.

# %%
def max_ring_size(mol):
    """Get the size of the largest ring in a molecule

    :param mol: input_molecule
    :return: size of the largest ring or 0 for an acyclic molecule
    """
    ri = mol.GetRingInfo()
    atom_rings = ri.AtomRings()
    if len(atom_rings) == 0:
        return 0
    else:
        return max([len(x) for x in ri.AtomRings()])

# %% [markdown]
# Now we can define the dictionary with the properties we want to calculate.

# %%
my_prop_dict = {
    "mw" : dm.descriptors.mw,
    "logp" : dm.descriptors.clogp,
    "hbd" : dm.descriptors.n_lipinski_hbd,
    "hba" : dm.descriptors.n_lipinski_hba,
    "max_ring_size" : max_ring_size
}

# %% [markdown]
# The datamol function **batch_compute_many_descriptors** returns a new dataframe with the computed descriptors. Note a couple of parameter settings.
# - add_properties=False - if this is set to True, all the supported descriptors are calculated
# - progress=True - show a progress bar

# %%
prop_df = dm.descriptors.batch_compute_many_descriptors(df.mol,properties_fn=my_prop_dict,add_properties=False,
                                             progress=True)

# %% [markdown]
# Now we have a dataframe with the properties, but it doesn't have any of the information from our original dataframe. We need to merge the two dataframes.

# %%
prop_df

# %% [markdown]
# Merge the descriptors into the main dataframe.

# %%
df = pd.concat([df,prop_df],axis=1)

# %% [markdown]
# ### Filtering a dataframe based on descriptor values
# Let's filter the dataframe to only include molecules meeting the Lipinski Rule of 5 (Ro5) criteria.  I see a lot of people doing this using the Pandas bracket notation to do something like this.
# ```python
# df = df[df['mw'] <= 500]
# df = df[df['logp'] <= 5]
# df = df[df['hbd'] <= 5]
# df = df[df['hba'] <= 10]
# ```
# To me, this feels convoluted. When I try to do this, I usuually forget the syntax or screw something up.  I prefer using the pandas [**query**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html) function.

# %%
df_ro5_ok = df.query("mw <= 500 and logp <= 5 and hbd <= 5 and hba <= 10")
len(df_ro5_ok)

# %% [markdown]
# We could also create a column indicating whether a molecule passed the Ro5

# %%
df['ro5_ok'] = (df.mw <= 500) & (df.logp <=5) & (df.hbd <= 5) & (df.hba <= 10)
df.ro5_ok.sum()

# %% [markdown]
# What if we want to count how many of the Ro5 criteria a molecule meets?  We could simply write a function to convert a boolean column to integers and calculate the sum of these integer columns.

# %%
def bool_to_int(bool_in):
    return bool_in.values.astype(int)

# %% [markdown]
# Now we can use the function above to count how many of the Ro5 rules a molecule passes.  A molecule that passes all the rules will have **ro5_count** set to 4.  As a check we can make sure the number of molecules passing all the rules is the same as what we calculated above.

# %%
df['ro5_count'] = bool_to_int(df.mw <= 500) + bool_to_int(df.logp <=5) + bool_to_int(df.hbd <= 5) + bool_to_int(df.hba <= 10)
len(df.query("ro5_count == 4"))

# %% [markdown]
# ### Clustering
# The datamol package provides a couple of useful functions for clustering.  The [**cluster_mols**](https://docs.datamol.io/stable/api/datamol.cluster.html) function provides a simple means of clustering based on the [Butina](https://pubs.acs.org/doi/pdf/10.1021/ci9803381) algorithm using the RDKit's Morgan fingerprints.  You can perform Butina clustering with the RDKit, but it takes a few more steps.
#
# When I look at the results of clustering, I like to see similar molecules aligned in a similar fashion.  Datamol has another convenience function [**auto_align_many**](https://docs.datamol.io/stable/api/datamol.align.html), that aligns molecules with the same scaffold.  Note that you can do clustering and alignment in one step with **auto_align_many**.  However, I prefer to do this as a two-step process that gives me a bit more control over the clustering and the alignment. Both **cluster_mols** and **auto_align_many** have several options.  Check out the docs for more information.

# %%
# cluster the molecules
cluster_list = dm.cluster_mols(df.mol)
# create a list to hold the cluster ids, which we will add to the dataframe
cluster_idx = [-1] * len(df)
for i,cluster in enumerate(tqdm(cluster_list[0])):
    # align the structures for each cluster using Bemis Murcko frameworks
    dm.align.auto_align_many([df.mol.values[x] for x in cluster],copy=False,partition_method='scaffold')
    # add the cluster id to cluster_idx
    for c in cluster:
        cluster_idx[c] = i
# add a column with cluster ids to the dataframe
df['cluster'] = cluster_idx
# Out:
#   0%|          | 0/3503 [00:00<?, ?it/s]

# %% [markdown]
# To get an overview of the data we'll create a dataframe with one example from each cluster.

# %%
cluster_sample_df = df.sort_values("cluster").drop_duplicates("cluster").copy()
cluster_sample_df.head()
# Out:
#                                                  SMILES           Name  pIC50  \
# 3888  c1ccc(cc1)c2ccc(cc2)c3c[nH]c(n3)C4Cc5c6ccccc6[...  CHEMBL3775414   7.77
# 1119  COc1ccc(cc1)CCN2C(CN(C2=O)NS(=O)(=O)C)c3ccc(cc...   CHEMBL571041   5.04
# 2356  CN1CCN(CC1)CCCNc2nnc(o2)c3ccc(cc3)NC(=O)c4ccccc4F  CHEMBL2022501   4.20
# 1230  Cc1c(ocn1)c2nnc(n2C)SCCCN3CC4CC4(C3)c5ccc(cc5)...  CHEMBL1081966   6.60
# 1222   Cc1c(ocn1)c2nnc(n2C)SCCCN3CC4CC4(C3)c5ccc(cc5)Cl  CHEMBL1080490   6.39
#
#       IC50                                            mol     mw  logp  hbd  \
# 3888  0.02  <rdkit.Chem.rdchem.Mol object at 0x13212a9d0> 474.24  6.58    3
# 1119  9.12  <rdkit.Chem.rdchem.Mol object at 0x1320c63b0> 457.13  3.20    1
# 2356 63.10  <rdkit.Chem.rdchem.Mol object at 0x1320f45f0> 438.22  3.18    2
# 1230  0.25  <rdkit.Chem.rdchem.Mol object at 0x1320cd4d0> 479.16  4.43    0
# 1222  0.41  <rdkit.Chem.rdchem.Mol object at 0x1320cd150> 429.14  4.19    0
#
#       hba  max_ring_size  ro5_ok  ro5_count  cluster
# 3888    5              6   False          3        0
# 1119    7              6    True          4        1
# 2356    8              6    True          4        2
# 1230    7              6    True          4        3
# 1222    6              6    True          4        4

# %% [markdown]
# I'd also like to see the size of each cluster.  We can use the Pandas [value_counts](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html) function to create a new dataframe with the cluster number and the number of molecules in each cluster.  We can then use the pandas [merge](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) function to combine **cluster_sample_df** and **cluster_count_df**.

# %%
cluster_count_df = df.cluster.value_counts().to_frame().reset_index()
cluster_count_df.columns = ["cluster","count"]
cluster_sample_df = cluster_sample_df.merge(cluster_count_df,on="cluster")
cluster_sample_df.head()
# Out:
#                                               SMILES           Name  pIC50  \
# 0  c1ccc(cc1)c2ccc(cc2)c3c[nH]c(n3)C4Cc5c6ccccc6[...  CHEMBL3775414   7.77
# 1  COc1ccc(cc1)CCN2C(CN(C2=O)NS(=O)(=O)C)c3ccc(cc...   CHEMBL571041   5.04
# 2  CN1CCN(CC1)CCCNc2nnc(o2)c3ccc(cc3)NC(=O)c4ccccc4F  CHEMBL2022501   4.20
# 3  Cc1c(ocn1)c2nnc(n2C)SCCCN3CC4CC4(C3)c5ccc(cc5)...  CHEMBL1081966   6.60
# 4   Cc1c(ocn1)c2nnc(n2C)SCCCN3CC4CC4(C3)c5ccc(cc5)Cl  CHEMBL1080490   6.39
#
#    IC50                                            mol     mw  logp  hbd  hba  \
# 0  0.02  <rdkit.Chem.rdchem.Mol object at 0x13212a9d0> 474.24  6.58    3    5
# 1  9.12  <rdkit.Chem.rdchem.Mol object at 0x1320c63b0> 457.13  3.20    1    7
# 2 63.10  <rdkit.Chem.rdchem.Mol object at 0x1320f45f0> 438.22  3.18    2    8
# 3  0.25  <rdkit.Chem.rdchem.Mol object at 0x1320cd4d0> 479.16  4.43    0    7
# 4  0.41  <rdkit.Chem.rdchem.Mol object at 0x1320cd150> 429.14  4.19    0    6
#
#    max_ring_size  ro5_ok  ro5_count  cluster  count
# 0              6   False          3        0     10
# 1              6    True          4        1     10
# 2              6    True          4        2      9
# 3              6    True          4        3      8
# 4              6    True          4        4      4

# %% [markdown]
# We can use mols2grid to display and scroll through the cluster samples

# %%
# This should work but the grid doesn't display on Colab
# mols2grid.display(cluster_sample_df,mol_col="mol",subset=["img","cluster","count"],use_coords=True, prerender=True)
# As workaround we have to do this on Colab.  If you're running on your own machine, substitute the line above
mols2grid.display(cluster_sample_df,mol_col="mol",subset=["img","cluster","count"])
# Out:
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# If we see an interesting cluster, we can use the function **show_cluster** to examine the molecules in that cluster.

# %%
def show_cluster(x):
    return mols2grid.display(df.query(f"cluster == {x}"),mol_col="mol",subset=["img","Name","pIC50"],use_coords=True, prerender=True, transform = {"pIC50" : lambda val: f"{val:.2f}"})

# %%
show_cluster(1)
# Out:
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;
